# %%
import pandas as pd
import numpy as np

# %%
airlines = pd.read_csv("../02-pandas/data/airlines.csv")
airports = pd.read_csv("../02-pandas/data/airports.csv")
flights = pd.read_csv("../02-pandas/data/flights.csv")
# Out:
# /tmp/ipykernel_1314/1188757705.py:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights = pd.read_csv("../02-pandas/data/flights.csv")

# %%
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
airports
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# ...

# %%
flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %% [markdown]
# Jakie jest maksymalne opóźnienie związane z pogodą?

# %%
result = (
    flights.loc[flights["WEATHER_DELAY"].isnull() == False, ["WEATHER_DELAY"]]
    .sort_values("WEATHER_DELAY", ascending=False)
    .head(1)
)
result
# Out:
#          WEATHER_DELAY
# 5642980         1211.0

# %% [markdown]
# Jakie było maksymalne opóźnienie lotu z Los Angeles, LAX to Atlanty, ATL w grudniu 2015?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'LAX') & (flights["DESTINATION_AIRPORT"] == 'ATL') 
    & (flights["MONTH"] == 12) & (flights["YEAR"] == 2015), :]
    .sort_values("ARRIVAL_DELAY", ascending=False)
)
result
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5812552  2015     12   31            4      DL            101      N138DL
# 5626116  2015     12   19            6      NK            474      N521NK
# 5704915  2015     12   24            4      DL           2032      N6712B
# 5570825  2015     12   16            3      WN           3150      N223WN
# 5611896  2015     12   18            5      DL           1654      N3741S
# ...       ...    ...  ...          ...     ...            ...         ...
# 5745327  2015     12   27            7      AA           1249      N030AA
# 5773987  2015     12   29            2      WN           3150      N273WN
# 5778262  2015     12   29            2      AA           1249      N021AA
# 5789624  2015     12   29            2      DL           1354      N1607B
# 5794488  2015     12   30            3      AA           1249      N001AA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'LAX') & (flights["DESTINATION_AIRPORT"] == 'ATL') 
    & (flights["MONTH"] == 12) & (flights["YEAR"] == 2015), ["ARRIVAL_DELAY"]]
    .sort_values("ARRIVAL_DELAY", ascending=False)
    .head(1)
)
result
# Out:
#          ARRIVAL_DELAY
# 5812552          296.0

# %% [markdown]
# Jaki był tail number lotu o maksymalnym opóźnienieniu z Los Angeles, LAX to Atlanty, ATL w grudniu 2015?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'LAX') & (flights["DESTINATION_AIRPORT"] == 'ATL') 
    & (flights["MONTH"] == 12) & (flights["YEAR"] == 2015), :]
    .sort_values("ARRIVAL_DELAY", ascending=False)
    .head(1)
)
result["TAIL_NUMBER"]
# Out:
# 5812552    N138DL
# Name: TAIL_NUMBER, dtype: object

# %% [markdown]
# Jakie było minimalne opóźnienie lotu z Los Angeles, LAX to Atlanty, ATL w grudniu 2015?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'LAX') & (flights["DESTINATION_AIRPORT"] == 'ATL') 
    & (flights["MONTH"] == 12) & (flights["YEAR"] == 2015), :]
    .sort_values("ARRIVAL_DELAY")
)
result
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5340299  2015     12    1            2      WN           3150      N704SW
# 5709169  2015     12   24            4      AA           2513      N005AA
# 5538371  2015     12   13            7      F9           1478      N232FR
# 5806154  2015     12   31            4      DL           1120      N844DN
# 5707850  2015     12   24            4      WN           2942      N7832A
# ...       ...    ...  ...          ...     ...            ...         ...
# 5745327  2015     12   27            7      AA           1249      N030AA
# 5773987  2015     12   29            2      WN           3150      N273WN
# 5778262  2015     12   29            2      AA           1249      N021AA
# 5789624  2015     12   29            2      DL           1354      N1607B
# 5794488  2015     12   30            3      AA           1249      N001AA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'LAX') & (flights["DESTINATION_AIRPORT"] == 'ATL') 
    & (flights["MONTH"] == 12) & (flights["YEAR"] == 2015), ["ARRIVAL_DELAY"]]
    .sort_values("ARRIVAL_DELAY")
    .head(1)
)
result
# Out:
#          ARRIVAL_DELAY
# 5340299          -36.0

# %% [markdown]
# Jaki był tail number lotu o minimalnym opóźnienieniu z Los Angeles, LAX to Atlanty, ATL w grudniu 2015?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'LAX') & (flights["DESTINATION_AIRPORT"] == 'ATL') 
    & (flights["MONTH"] == 12) & (flights["YEAR"] == 2015), :]
    .sort_values("ARRIVAL_DELAY")
    .head(1)
)
result["TAIL_NUMBER"]
# Out:
# 5340299    N704SW
# Name: TAIL_NUMBER, dtype: object

# %% [markdown]
# Jaki był najdłuższy czas lotu (czas spędzony w powietrzu) z Honolulu, HNL gdziekolwiek?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == "HNL")]
    .sort_values("AIR_TIME", ascending=False)
    .head(1))
    
result
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 2978579  2015      7    6            1      HA             50      N383HA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 2978579            HNL                 JFK                 1520  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 2978579         818.0           83.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 2978579                  NaN               0.0             0.0            4.0
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 2978579                  0.0           79.0
#
# [1 rows x 31 columns]

# %%
result[["AIR_TIME"]]
# Out:
#          AIR_TIME
# 2978579     630.0

# %% [markdown]
# (Do powyższego) Dokąd odbył sie ten lot?

# %%
result[["DESTINATION_AIRPORT"]]
# Out:
#         DESTINATION_AIRPORT
# 2978579                 JFK

# %% [markdown]
# (Do powyższego) Jaka linia go wykonała?

# %%
result[["AIRLINE"]]
# Out:
#         AIRLINE
# 2978579      HA

# %%
airlines.loc[airlines["IATA_CODE"] == 'HA']
# Out:
#    IATA_CODE                 AIRLINE
# 11        HA  Hawaiian Airlines Inc.

# %% [markdown]
# Jaki był minimalny czas lotu (czas w powietrzu) na trasie pomiędzy lotniskami Chicago, ORD i Austin, AUS (tam i z powrotem)?

# %%
result = (
    flights[(flights["DESTINATION_AIRPORT"].isin(["ORD", "AUS"])) & (flights["ORIGIN_AIRPORT"].isin(["ORD", "AUS"]))]
    .sort_values("AIR_TIME")
)
result[["DESTINATION_AIRPORT", "ORIGIN_AIRPORT", "AIR_TIME"]].head(1)
# Out:
#         DESTINATION_AIRPORT ORIGIN_AIRPORT  AIR_TIME
# 5133601                 ORD            AUS     107.0

# %% [markdown]
# Jaki był średni czas lotu (czas w powietrzu) na trasie pomiędzy lotniskami Chicago, ORD i Austin, AUS (tam i z powrotem)?

# %%
result["AIR_TIME"].mean()
# Out:
# 133.81096451319382

# %% [markdown]
# Jaka była mediana czasu lotu (czas w powietrzu) na trasie pomiędzy lotniskami Chicago, ORD i Austin, AUS (tam i z powrotem)?

# %%
result["AIR_TIME"].median()
# Out:
# 132.0

# %% [markdown]
# Jaki był maksymalny czas lotu (czas w powietrzu) na trasie pomiędzy lotniskami Chicago, ORD i Austin, AUS (tam i z powrotem)?

# %%
result = (
    flights[(flights["DESTINATION_AIRPORT"].isin(["ORD", "AUS"])) & (flights["ORIGIN_AIRPORT"].isin(["ORD", "AUS"]))]
    .sort_values("AIR_TIME", ascending=False)
)
result[["DESTINATION_AIRPORT", "ORIGIN_AIRPORT", "AIR_TIME"]].head(1)
# Out:
#        DESTINATION_AIRPORT ORIGIN_AIRPORT  AIR_TIME
# 933026                 AUS            ORD     201.0

# %% [markdown]
# Jaka linia lata z Yumy, YUM?

# %%
result = (
    flights.loc[flights["ORIGIN_AIRPORT"] == 'YUM']
)
result["AIRLINE"].drop_duplicates()
# Out:
# 1687    OO
# Name: AIRLINE, dtype: object

# %%
airlines.loc[airlines["IATA_CODE"] == 'OO']
# Out:
#   IATA_CODE                AIRLINE
# 5        OO  Skywest Airlines Inc.

# %% [markdown]
# Ile lotów odbyło się z Yumy, YUM w 2015?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'YUM') & (flights["YEAR"] == 2015)]
)

len(result)
# Out:
# 1877

# %% [markdown]
# Jaka trasa ma najkrótsze czasy lotów?
# Odpowiedź podaj jako sklejenie nazw lotnisk, 6liter, na przykład LAXJFK, JFKLAX. Obie odpowiedzi będą zaliczone.

# %%
flights.groupby(["ORIGIN_AIRPORT", "DESTINATION_AIRPORT"]).mean().sort_values(["AIR_TIME"])["AIR_TIME"]
# Out:
# ORIGIN_AIRPORT  DESTINATION_AIRPORT
# 14256           15841                   9.000000
# WRG             PSG                    11.233846
# 14256           15841                  11.758621
# PSG             WRG                    11.895706
# 15841           14256                  11.923077
#                                          ...
# SGF             HYS                          NaN
# STL             PIA                          NaN
# SWF             LGA                          NaN
# TYS             CLL                          NaN
#                 LEX                          NaN
# Name: AIR_TIME, Length: 12377, dtype: float64

# %%
# ??
airports.loc[airports["IATA_CODE"] == 14256]
# Out:
# Empty DataFrame
# Columns: [IATA_CODE, AIRPORT, CITY, STATE, COUNTRY, LATITUDE, LONGITUDE]
# Index: []

# %% [markdown]
# Znajdź najdłużej trwający lot (czas w powietrzu), nie z  JFK. Policz średnią długość lotu pomiędzy lotniskami tego lotu.

# %%
result = (
    flights.loc[flights["ORIGIN_AIRPORT"] != 'JFK']
    .sort_values("AIR_TIME", ascending=False)
)

result[["ORIGIN_AIRPORT", "AIR_TIME"]].head(1)
# Out:
#        ORIGIN_AIRPORT  AIR_TIME
# 565155            EWR     683.0

# %%
flights.loc[flights["ORIGIN_AIRPORT"] != 'JFK', ["AIR_TIME"]].mean()
# Out:
# AIR_TIME    112.097795
# dtype: float64

# %% [markdown]
# Jaki jest średni czas lotu (czas w powietrzu) z Honolulu, HNL do Nowego Jorku, JFK?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'HNL') & (flights["DESTINATION_AIRPORT"] == 'JFK')]
)

result["AIR_TIME"].mean()
# Out:
# 546.4490445859873

# %% [markdown]
# Jaki jest średni czas lotu (czas w powietrzu) z Nowego Jorku, JFK do Honolulu, HNL?

# %%
result = (
    flights.loc[(flights["ORIGIN_AIRPORT"] == 'JFK') & (flights["DESTINATION_AIRPORT"] == 'HNL')]
)

result["AIR_TIME"].mean()
# Out:
# 635.2070063694267
